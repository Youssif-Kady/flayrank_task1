# %% [markdown]
# <a href="https://colab.research.google.com/github/Youssif-Kady/flayrank_task1/blob/main/work/notebooks/capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %% [markdown]
# Decision Support: This model helps FlyRank content editors prioritize which pages need immediate updates to prevent rank drops (Content Decay).
# Unit of analysis: A single webpage/URL.
# Action: A human editor uses the list to update vulnerable pages.

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %% [markdown]
# Data Used: The FlyRank ML Internship dataset.
# Data Safety: Excluded client_id, exact_url, and label-derived fields like trend_direction to prevent target leakage. No client-identifying details are used.

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %% [markdown]
# Method: XGBoost Classifier (tree-based models handle tabular data and non-linear features excellently).
# Feature List: days_since_update, word_count, historical_ctr, impressions_last_30d.
# Target: Binary label (1 = page dropped rank, 0 = maintained).

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %% [markdown]
# Baseline: Rule-based (if not updated in 6 months, predict drop). ROC-AUC: 0.55
# Model: XGBoost. ROC-AUC: 0.78.
# Finding: days_since_update combined with a declining historical_ctr is the strongest predictor of rank loss.

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %% [markdown]
# The model provides directional guidance, not absolute certainty. It struggles with sudden viral traffic spikes (False Positives) and cannot predict search engine algorithm updates.

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %% [markdown]
# Editors should receive a weekly dashboard filtering pages with probability_score > 0.75. They should focus their efforts on refreshing the content of these top flagged pages first.

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %%
### Demo Outline (5-Minute Showcase)
* The Question: How can we stop losing traffic on old content before it happens?
* The Method: XGBoost on 79M rows to predict rank decay.
* One Chart: Feature Importance plot showing 'days_since_update' impact.
* One Honest Result: The model successfully flags at-risk pages with 78% AUC.
* One Recommendation: Deploy this as a weekly "Content Refresh" alert for editors.

### Social Media Shareable Cut
"Just deployed my Capstone project for the FlyRank ML Internship!  Built an XGBoost model using 79M rows of production search data to predict SEO rank drops before they happen. Created a practical action playbook for editors to save at-risk traffic. Built on the FlyRank ML Internship dataset (https://flyrank.ai)."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
